# %% [markdown]
# <a href="https://colab.research.google.com/github/JennaEscheik/PUBH1142/blob/main/HW_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Question 1
# Define a list in Python

# %%
my_list = [1, 2, 3, 4, 5]
print(my_list)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ## Question 2
# Access the third element of my_list

# %%
print(my_list[2])  # index starts at 0
# Out:
# 3

# %% [markdown]
# ## Question 3
# Add "new_item" to the end of my_list

# %%
my_list.append("new_item")
print(my_list)
# Out:
# [1, 2, 3, 4, 5, 'new_item']

# %% [markdown]
# ## Question 4
# Create a tuple with "apple", "banana", "cherry"

# %%
my_tuple = ("apple", "banana", "cherry")
print(my_tuple)
# Out:
# ('apple', 'banana', 'cherry')

# %% [markdown]
# ## Question 5
# Access the first element of my_tuple

# %%
print(my_tuple[0])
# Out:
# apple

# %% [markdown]
# ## Question 6
# Define dictionary with keys "name", "age"

# %%
my_dict = {"name": "John Doe", "age": 30}
print(my_dict)
# Out:
# {'name': 'John Doe', 'age': 30}

# %% [markdown]
# ## Question 7
# Retrieve value for key "name"

# %%
print(my_dict["name"])
# Out:
# John Doe

# %% [markdown]
# ## Question 8
# Change value of "age" to 35

# %%
my_dict["age"] = 35
print(my_dict)
# Out:
# {'name': 'John Doe', 'age': 35}

# %% [markdown]
# ## Question 9
# Add key-value pair "city":"New York"

# %%
my_dict["city"] = "New York"
print(my_dict)
# Out:
# {'name': 'John Doe', 'age': 35, 'city': 'New York'}

# %% [markdown]
# ## Question 10
# Create a set with "apple", "banana", "cherry"

# %%
my_set = {"apple", "banana", "cherry"}
print(my_set)
# Out:
# {'banana', 'apple', 'cherry'}

# %% [markdown]
# ## Question 11
# Add "orange" to my_set

# %%
my_set.add("orange")
print(my_set)
# Out:
# {'banana', 'orange', 'apple', 'cherry'}

# %% [markdown]
# ## Question 12
# Remove "banana" from my_set

# %%
my_set.remove("banana")
print(my_set)
# Out:
# {'orange', 'apple', 'cherry'}

# %% [markdown]
# ## Question 13
# Length of list [1,2,3,4,5]

# %%
print(len([1, 2, 3, 4, 5]))
# Out:
# 5

# %% [markdown]
# ## Question 14
# Result of [1,2,3] * 2

# %%
print([1, 2, 3] * 2)
# Out:
# [1, 2, 3, 1, 2, 3]

# %% [markdown]
# ## Question 15
# Result of set([1,2,2,3,4,4,4,5,5])

# %%
print(set([1,2,2,3,4,4,4,5,5]))
# Out:
# {1, 2, 3, 4, 5}
