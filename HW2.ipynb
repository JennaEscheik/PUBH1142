# %% [markdown]
# <a href="https://colab.research.google.com/github/JennaEscheik/PUBH1142/blob/main/HW2_Python_Collections.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HW2 – Python Collections (Lesson 7)
# Jenna Escheik

# %% [markdown]
# ## Quiz Answers

# %% [markdown]
# ### 1) How do you define a list in Python?
#
# **Answer:** You define a list using square brackets [], with items separated by commas.
#
# ```python
# my_list = [1, 2, 3]
# ```

# %% [markdown]
# ### 2) How do you access the third element of a Python list named my_list?
#
# **Answer:** Use index 2 (because indexing starts at 0).
#
# ```python
# my_list[2]
# ```

# %% [markdown]
# ### 3) How can you add the element "new_item" to the end of an existing list named my_list?
#
# **Answer:** Use the .append() method.
#
# ```python
# my_list.append("new_item")
# ```

# %% [markdown]
# ### 4) How do you create a Python tuple with the items "apple", "banana", and "cherry"?
#
# **Answer:** Use parentheses () (a tuple is immutable).
#
# ```python
# my_tuple = ("apple", "banana", "cherry")
# ```

# %% [markdown]
# ### 5) How do you access the first element of a Python tuple named my_tuple?
#
# **Answer:** Use index 0.
#
# ```python
# my_tuple[0]
# ```

# %% [markdown]
# ### 6) How do you define a dictionary in Python with keys "name", "age" and values "John Doe", 30?
#
# **Answer:** Use curly braces {} with key–value pairs separated by colons.
#
# ```python
# my_dict = {"name": "John Doe", "age": 30}
# ```

# %% [markdown]
# ### 7) How can you retrieve the value for the key "name" from the dictionary my_dict?
#
# **Answer:** Use bracket notation (or .get() as an alternative).
#
# ```python
# my_dict["name"]
# # or
# my_dict.get("name")
# ```

# %% [markdown]
# ### 8) How can you change the value associated with the key "age" in the dictionary my_dict to 35?
#
# **Answer:** Reassign the value using the key.
#
# ```python
# my_dict["age"] = 35
# ```

# %% [markdown]
# ### 9) How can you add a new key-value pair "city":"New York" to the dictionary my_dict?
#
# **Answer:** Assign a new key with a value.
#
# ```python
# my_dict["city"] = "New York"
# ```

# %% [markdown]
# ### 10) How do you create a set in Python with the items "apple", "banana", and "cherry"?
#
# **Answer:** Use curly braces {} with items (sets store unique elements).
#
# ```python
# my_set = {"apple", "banana", "cherry"}
# ```

# %% [markdown]
# ### 11) How do you add the item "orange" to an existing set my_set?
#
# **Answer:** Use the .add() method.
#
# ```python
# my_set.add("orange")
# ```

# %% [markdown]
# ### 12) How do you remove the item "banana" from the set my_set?
#
# **Answer:** Use .remove() (or .discard() if you want to avoid an error when missing).
#
# ```python
# my_set.remove("banana")
# # or
# my_set.discard("banana")
# ```

# %% [markdown]
# ### 13) What is the length of a list my_list with elements [1, 2, 3, 4, 5]?
#
# **Answer:** The length is 5.
#
# ```python
# len([1, 2, 3, 4, 5])  # 5
# ```

# %% [markdown]
# ### 14) What will be the result of my_list * 2 if my_list is [1, 2, 3]?
#
# **Answer:** The list repeats its elements twice.
#
# ```python
# [1, 2, 3] * 2
# # [1, 2, 3, 1, 2, 3]
# ```

# %% [markdown]
# ### 15) What is the result of set([1,2,2,3,4,4,4,5,5])?
#
# **Answer:** Duplicates are removed, leaving unique elements (order may vary).
#
# ```python
# set([1,2,2,3,4,4,4,5,5])
# # {1, 2, 3, 4, 5}
# ```
