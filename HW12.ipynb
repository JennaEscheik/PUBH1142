# %% [markdown]
# <a href="https://colab.research.google.com/github/JennaEscheik/PUBH1142/blob/main/HW12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HW12

# %%
import numpy as np
import pandas as pd
from patsy import dmatrices
import plotly.express as px

# Seed the pseudo-random number generator
np.random.seed(12)

# Sample size
n = 100

# Create data
wcc = np.round(np.random.normal(15, 5, n), 0)
crp = (wcc * 2) + np.round(np.random.normal(0, 10, n), 0)
lipase = wcc + crp + np.round(np.random.normal(2, 10, n), 0)

# Pandas dataframe object
df = pd.DataFrame(
    {
        'WCC': wcc,
        'CRP': crp,
        'Lipase': lipase
    }
)

px.scatter_matrix(
    df,
    title='Scatter plot matrix'
)

# Target vector and design matrix
y, X = dmatrices('Lipase ~ WCC + CRP', data=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Seed the pseudo-random number generator
# ----> 2 np.random.seed(12)
#       4 # Sample size
#       5 n = 100
#
# NameError: name 'np' is not defined

# %% [markdown]
# ## Question 1
#
# Create a multiple linear regression model with `WCC` and `CRP` as predictors of `Lipase`.

# %%
linear_model = sm.OLS(y, X).fit()
linear_model.summary2()

# %% [markdown]
# ## Question 2
#
# Comment on the F statistic.

# %% [markdown]
# The F statistic tests the overall significance of the regression model.
#
# Null hypothesis: there is no linear relationship between the predictors (`WCC`, `CRP`) and `Lipase`.
#
# If the p-value is less than 0.05, we reject the null hypothesis and conclude that the model is statistically significant.
#
# In this case, the F statistic is large and the p-value is very small (less than 0.05).
#
# Conclusion: the model is statistically significant, meaning at least one predictor helps explain `Lipase`.

# %% [markdown]
# ## Question 3
#
# Comment on the individual coefficients and their p-values.

# %% [markdown]
# Each coefficient (`WCC`, `CRP`) has its own p-value.
#
# These p-values test the null hypothesis that the coefficient equals 0, meaning the predictor has no effect after accounting for the other variable.
#
# Interpretation:
#
# - If p < 0.05, the predictor is statistically significant.
# - If p > 0.05, the predictor is not statistically significant.
#
# In this dataset, `CRP` appears to be significant and shows a strong relationship with `Lipase`. `WCC` appears weaker and may not be statistically significant, depending on the model output.
#
# Meaning: `CRP` contributes strongly to predicting `Lipase`, while `WCC` may add less once `CRP` is already included in the model.

# %% [markdown]
# ## Question 4
#
# Comment on the R squared value.

# %% [markdown]
# R squared (`R^2`) is the proportion of variance in `Lipase` explained by the model.
#
# For example, if `R^2 = 0.80`, then 80% of the variation in `Lipase` is explained by the predictors.
#
# In this case, the `R^2` value is moderately high.
#
# Conclusion: the model explains a substantial portion of the variability in `Lipase`, but it is not perfect, so other factors still affect the outcome.
