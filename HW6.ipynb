# %% [markdown]
# <a href="https://colab.research.google.com/github/JennaEscheik/PUBH1142/blob/main/HW6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Question 1
# Calculate the following expressions

# %%
# Calculate: 3 * 8
result1 = 3 * 8
print(result1)

# Calculate: (33 + 7) / 5
result2 = (33 + 7) / 5
print(result2)
# Out:
# 24
# 8.0

# %% [markdown]
# ## Question 2
# Determine the data types of 1+2 and 1+2.

# %%
# What is the type of 1+2?
print(type(1 + 2))

# What is the type of 1+2. ?
print(type(1 + 2.))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# ## Question 3
# Generate a loop that prints n^2 for n = 1 to 5

# %%
# Print the square of each number from 1 to 5
for n in range(1, 6):
    print(n ** 2)
# Out:
# 1
# 4
# 9
# 16
# 25

# %% [markdown]
# ## Question 4
# Create i = 1, increment i until i^2 exceeds 1000, and print final value of i

# %%
i = 1

while i ** 2 < 1000:
    i += 1

print(i)
# Out:
# 32
